# %% [markdown]
# Trying to open the spss or stata file using python :(

# %%
import pandas as pd

# %% [markdown]
# use pandas.read_stata https://pandas.pydata.org/pandas-docs/version/0.21/generated/pandas.read_stata.html

# %% [markdown]
# value are not unique? https://stackoverflow.com/questions/31782283/loading-stata-file-categorial-values-must-be-unique

# %%
df = pd.read_stata("WV6_Stata_v_2016_01_01.dta", convert_categoricals=False)

# %%
df.head(25)
# Out:
#     V1  V2  V2A    V3  V4  V5  V6  V7  V8  V9    ...     I_HOMOLIB  \
# 0    6  12   12   1.0   1   1   1  -2   1   1    ...      0.000000
# 1    6  12   12   2.0   1   2   3   4   2   2    ...      0.000000
# 2    6  12   12   3.0   1   3   2   4   2   1    ...      0.000000
# 3    6  12   12   4.0   1   1   3   4   3   1    ...      0.000000
# 4    6  12   12   5.0   1   1   1   2   1   1    ...      0.000000
# 5    6  12   12   6.0   1   2   2   2   4   1    ...      0.000000
# 6    6  12   12   7.0   1   1   1   1   1   1    ...      0.000000
# 7    6  12   12   8.0   1   1   1   1   2   2    ...      0.000000
# 8    6  12   12   9.0   1   1   1   2   2   2    ...      0.000000
# 9    6  12   12  10.0   1   1   1   2   1   1    ...      0.000000
# 10   6  12   12  11.0   1   2   3   4   1   1    ...      0.000000
# 11   6  12   12  12.0   1   1   2   3   2   2    ...      0.000000
# 12   6  12   12  13.0   1   2   3   3   4   4    ...      0.000000
# ...

# %%
df.tail(25)
# Out:
#        V1   V2  V2A      V3  V4  V5  V6  V7  V8  V9    ...     I_HOMOLIB  \
# 90325   6  716  716  1476.0   1   3   2   1   2   1    ...      0.000000
# 90326   6  716  716  1477.0   1   2   1   2   1   1    ...      0.000000
# 90327   6  716  716  1478.0   1   1   1   1   1   1    ...      0.000000
# 90328   6  716  716  1479.0   1   2   2   3   1   1    ...      0.000000
# 90329   6  716  716  1480.0   2   1   2   3   1   1    ...      0.333333
# 90330   6  716  716  1481.0   1   1   1   4   1   1    ...      0.000000
# 90331   6  716  716  1482.0   1   1   1   1   1   1    ...      0.000000
# 90332   6  716  716  1483.0   1   1   1   2   1   2    ...      0.000000
# 90333   6  716  716  1484.0   1   2   1   2   1   1    ...      0.000000
# 90334   6  716  716  1485.0   1   1   1   1   1   1    ...      0.000000
# 90335   6  716  716  1486.0   1   1   1   3   1   1    ...      0.000000
# 90336   6  716  716  1487.0   1   1   1   3   1   1    ...      0.000000
# ...

# %% [markdown]
# WE OPENED IT!

# %% [markdown]
# open columns

# %%
headers = df.columns

# %%
pd.set_option('display.max_columns', None)

# %%
pd.set_option('display.max_rows', None)

# %%
type(headers)
# Out:
# pandas.core.indexes.base.Index

# %%
list(df.columns.values)
# Out:
# ['V1',
#  'V2',
#  'V2A',
#  'V3',
#  'V4',
#  'V5',
#  'V6',
#  'V7',
#  'V8',
#  'V9',
#  'V10',
#  'V11',
#  'V12',
#  'V13',
#  'V14',
#  'V15',
#  'V16',
#  'V17',
#  'V18',
#  'V19',
#  'V20',
#  'V21',
#  'V22',
#  'V23',
#  'V24',
#  'V25',
#  'V26',
#  'V27',
#  'V28',
#  'V29',
#  'V30',
#  'V31',
#  'V32',
#  'V33',
#  'V34',
#  'V35',
#  'V36',
#  'V37',
#  'V38',
#  'V39',
#  'V40',
#  'V41',
#  'V42',
#  'V43',
#  'V44',
#  'V44_ES',
#  'V45',
#  'V46',
#  'V47',
#  'V48',
#  'V49',
#  'V50',
#  'V51',
#  'V52',
#  'V53',
#  'V54',
#  'V55',
#  'V56',
#  'V56_NZ',
#  'V57',
#  'V58',
#  'V59',
#  'V60',
#  'V61',
#  'V62',
#  'V63',
#  'V64',
#  'V65',
#  'V66',
#  'V67',
#  'V68',
#  'V69',
#  'V70',
#  'V71',
#  'V72',
#  'V73',
#  'V74',
#  'V74B',
#  'V75',
#  'V76',
#  'V77',
#  'V78',
#  'V79',
#  'V80',
#  'V81',
#  'V82',
#  'V83',
#  'V84',
#  'V85',
#  'V86',
#  'V87',
#  'V88',
#  'V89',
#  'V90',
#  'V91',
#  'V92',
#  'V93',
#  'V94',
#  'V95',
#  'V96',
# ...

# %%
df['V228']
# Out:
# 0         12005
# 1         12007
# 2            -2
# 3            -2
# 4             2
# 5         12006
# 6             2
# 7         12007
# 8         12007
# 9         12001
# 10        12007
# 11        12006
# 12        12007
# 13            2
# 14        12007
# 15        12007
# 16        12006
# 17        12007
# 18           -2
# 19        12006
# 20            2
# 21            2
# 22            5
# 23        12008
# 24        12008
# 25            2
# 26            2
# 27        12013
# 28        12002
# 29        12001
# 30        12014
# 31        12007
# 32        12005
# 33        12006
# 34        12007
# 35        12009
# 36        12001
# 37        12001
# 38        12001
# 39        12001
# 40            2
# 41        12006
# 42           -2
# 43        12001
# 44        12008
# 45        12001
# 46            2
# 47        12008
# 48        12001
# 49            2
# 50        12002
# 51           -2
# 52            2
# 53        12006
# 54            2
# ...
