# %% [markdown]
# opening a saved .dta file

# %%
import pandas as pd

# %%
df = pd.read_stata("russia.dta", convert_categoricals=False)

# %%
df.head(25)
# Out:
#     index  V1   V2  V2A    V3  V4  V5  V6  V7  V8    ...     I_HOMOLIB  \
# 0   61177   6  643  643   1.0   1   1   2   3   2    ...      0.222222
# 1   61178   6  643  643   2.0   2   2   1   4   1    ...      0.222222
# 2   61179   6  643  643   3.0   2   1   1   4   3    ...      0.222222
# 3   61180   6  643  643   4.0   1   2   2   4   2    ...      0.222222
# 4   61181   6  643  643   5.0   1   1   2   3   2    ...      0.444444
# 5   61182   6  643  643   6.0   1   1   2   3   2    ...      0.222222
# 6   61183   6  643  643   7.0   1   1   2   3   1    ...      0.333333
# 7   61184   6  643  643   8.0   1   1   2   3   2    ...      0.222222
# 8   61185   6  643  643   9.0   1   1   2   3   2    ...      0.222222
# 9   61186   6  643  643  10.0   1   3   2   4   1    ...      0.222222
# 10  61187   6  643  643  11.0   2   2   1   4   1    ...      0.222222
# 11  61188   6  643  643  12.0   2   2   1   4   1    ...      0.222222
# ...

# %%
df.tail(25)
# Out:
#       index  V1   V2  V2A      V3  V4  V5  V6  V7  V8    ...     I_HOMOLIB  \
# 2475  63652   6  643  643  2476.0   1   2   2   2   2    ...      0.444444
# 2476  63653   6  643  643  2477.0   2   2   2   3   1    ...      0.666667
# 2477  63654   6  643  643  2478.0   1   1   1   3   1    ...      0.000000
# 2478  63655   6  643  643  2479.0   1   2   2   4   1    ...      0.000000
# 2479  63656   6  643  643  2480.0   1   2   2   3   2    ...      0.000000
# 2480  63657   6  643  643  2481.0   1   2   2   4   1    ...      0.000000
# 2481  63658   6  643  643  2482.0   1   1   1   2   1    ...      0.111111
# 2482  63659   6  643  643  2483.0   2   2   2   3   2    ...      0.000000
# 2483  63660   6  643  643  2484.0   3   3   4   4   4    ...           NaN
# 2484  63661   6  643  643  2485.0   1   2   1   3   3    ...      0.333333
# 2485  63662   6  643  643  2486.0   1   2   4   4  -5    ...      0.000000
# ...
